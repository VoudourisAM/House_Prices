# %%
#Importing-Libraries#

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import LabelEncoder
# creating instance of labelencoder
labelencoder = LabelEncoder()

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
lr = LinearRegression()
#----------------------------------------------------------

# %%
tr_data = pd.read_csv('...')
tr_data.drop('Id', axis=1, inplace=True)

tt_data = pd.read_csv('...')
tt_data.drop('Id', axis=1, inplace=True)

feature = pd.read_csv('...')
feature.drop('Id', axis=1, inplace=True)

# %%
tr_data.head(5)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 3         Lvl    AllPub    Corner  ...        0    NaN   NaN         NaN
# 4         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# ...

# %%
print('Information of Train-Dataset:')
tr_data.info()
print('--------------------')
print('Information of Test-Dataset:')
tt_data.info()
# Out:
# Information of Train-Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
for i in tr_data:
    if tr_data[i].isnull().any():
        print('This column have null values: {}' .format(i))
# Out:
# This column have null values: LotFrontage
# This column have null values: Alley
# This column have null values: MasVnrType
# This column have null values: MasVnrArea
# This column have null values: BsmtQual
# This column have null values: BsmtCond
# This column have null values: BsmtExposure
# This column have null values: BsmtFinType1
# This column have null values: BsmtFinType2
# This column have null values: Electrical
# This column have null values: FireplaceQu
# This column have null values: GarageType
# This column have null values: GarageYrBlt
# This column have null values: GarageFinish
# This column have null values: GarageQual
# This column have null values: GarageCond
# This column have null values: PoolQC
# This column have null values: Fence
# This column have null values: MiscFeature

# %%
sns.heatmap(tr_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
# The colums who has 45% missing values dropping

Tr_Ms_Values = tr_data.isnull().sum()
Tr_Percent = (45/100) * len(tr_data)

print('Drop the columns which has 45% missing values')
print()
print()

for i in tr_data:
    #print('The columns: {} has {:.2f}% missing values'.format(i,(Ms_Values[i]/len(Tr_Data)*100)))
    if Tr_Ms_Values[i] > Tr_Percent:
        print()
        print('The columns: {} has {:.2f}% missing value and will be deleted'.format(i,(Tr_Ms_Values[i]/len(tr_data)*100)))
        print()
        tr_data.drop(i,axis=1, inplace=True)
        tt_data.drop(i,axis=1, inplace=True)
# Out:
# Drop the columns which has 45% missing values
#
#
#
# The columns: Alley has 93.77% missing value and will be deleted
#
#
# The columns: FireplaceQu has 47.26% missing value and will be deleted
#
#
# The columns: PoolQC has 99.52% missing value and will be deleted
#
#
# The columns: Fence has 80.75% missing value and will be deleted
#
#
# The columns: MiscFeature has 96.30% missing value and will be deleted

# %%
tr_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   LotShape       1460 non-null   object
#  6   LandContour    1460 non-null   object
#  7   Utilities      1460 non-null   object
#  8   LotConfig      1460 non-null   object
#  9   LandSlope      1460 non-null   object
#  10  Neighborhood   1460 non-null   object
#  11  Condition1     1460 non-null   object
#  12  Condition2     1460 non-null   object
#  13  BldgType       1460 non-null   object
#  14  HouseStyle     1460 non-null   object
#  15  OverallQual    1460 non-null   int64
#  16  OverallCond    1460 non-null   int64
# ...

# %%
for i in tr_data:
    
    if (tr_data[i].dtype == 'object') and (tr_data[i].isnull().sum() > 0 ):
        print('The columns is {} and have {} null values from {} and data-type is object.'.format(i,tr_data[i].isnull().sum(), len(tr_data.index)))
        print(tr_data[i].value_counts()) 
        print()
    elif ((tr_data[i].dtype == 'int') or (tr_data[i].dtype == 'float')) and (tr_data[i].isnull().sum() > 0 ):
        print('The columns is {} and have {} null values from {} and data-type is {}.'.format(i,tr_data[i].isnull().sum(),len(tr_data.index),tr_data[i].dtype))
        tr_data[i].bfill(axis ='rows', inplace=True) # Fill across the row
        print()
        
        
tr_data['MasVnrType'].fillna('None', inplace=True)
tr_data['BsmtQual'].fillna('TA', inplace=True)
tr_data['BsmtCond'].fillna('TA', inplace=True)
tr_data['BsmtExposure'].fillna('No', inplace=True)
tr_data['BsmtFinType1'].fillna('Unf', inplace=True)
tr_data['BsmtFinType2'].fillna('Unf', inplace=True)
tr_data['Electrical'].fillna('SBrkr', inplace=True)
tr_data['GarageType'].fillna('Attchd', inplace=True)
tr_data['GarageFinish'].fillna('Unf', inplace=True)
tr_data['GarageQual'].fillna('TA', inplace=True)
tr_data['GarageCond'].fillna('TA', inplace=True)
# Out:
# The columns is LotFrontage and have 259 null values from 1460 and data-type is float64.
#
# The columns is MasVnrType and have 8 null values from 1460 and data-type is object.
# None       864
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: MasVnrType, dtype: int64
#
# The columns is MasVnrArea and have 8 null values from 1460 and data-type is float64.
#
# The columns is BsmtQual and have 37 null values from 1460 and data-type is object.
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: BsmtQual, dtype: int64
#
# The columns is BsmtCond and have 37 null values from 1460 and data-type is object.
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: BsmtCond, dtype: int64
#
# The columns is BsmtExposure and have 38 null values from 1460 and data-type is object.
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: BsmtExposure, dtype: int64
#
# The columns is BsmtFinType1 and have 37 null values from 1460 and data-type is object.
# Unf    430
# GLQ    418
# ...

# %%
for i in tt_data:
    
    if (tt_data[i].dtype == 'object') and (tt_data[i].isnull().sum() > 0 ):
        print('The columns is {} and have {} null values from {} and data-type is object.'.format(i,tt_data[i].isnull().sum(), len(tt_data.index)))
        print(tt_data[i].value_counts()) 
        print()
    elif ((tt_data[i].dtype == 'int') or (tt_data[i].dtype == 'float')) and (tt_data[i].isnull().sum() > 0 ):
        print('The columns is {} and have {} null values from {} and data-type is {}.'.format(i,tt_data[i].isnull().sum(),len(tt_data.index),tt_data[i].dtype))
        tt_data[i].bfill(axis ='rows', inplace=True) # Fill across the row
        print()
        
        
tt_data['MSZoning'].fillna('RL', inplace=True)
tt_data['Utilities'].fillna('AllPub', inplace=True)
tt_data['Exterior1st'].fillna('VinylSd', inplace=True)
tt_data['Exterior2nd'].fillna('VinylSd', inplace=True)
tt_data['MasVnrType'].fillna('None', inplace=True)
tt_data['BsmtQual'].fillna('TA', inplace=True)
tt_data['BsmtCond'].fillna('TA', inplace=True)
tt_data['BsmtExposure'].fillna('No', inplace=True)
tt_data['BsmtFinType1'].fillna('GLQ', inplace=True)
tt_data['BsmtFinType2'].fillna('Unf', inplace=True)
tt_data['KitchenQual'].fillna('TA', inplace=True)
tt_data['Functional'].fillna('Typ', inplace=True)
tt_data['GarageType'].fillna('Attchd', inplace=True)
tt_data['GarageFinish'].fillna('Unf', inplace=True)
tt_data['GarageQual'].fillna('TA', inplace=True)
tt_data['GarageCond'].fillna('TA', inplace=True)
tt_data['SaleType'].fillna('WD', inplace=True)
# Out:
# The columns is MSZoning and have 4 null values from 1459 and data-type is object.
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: MSZoning, dtype: int64
#
# The columns is LotFrontage and have 227 null values from 1459 and data-type is float64.
#
# The columns is Utilities and have 2 null values from 1459 and data-type is object.
# AllPub    1457
# Name: Utilities, dtype: int64
#
# The columns is Exterior1st and have 1 null values from 1459 and data-type is object.
# VinylSd    510
# MetalSd    230
# HdBoard    220
# Wd Sdng    205
# Plywood    113
# CemntBd     65
# BrkFace     37
# WdShing     30
# AsbShng     24
# Stucco      18
# BrkComm      4
# CBlock       1
# AsphShn      1
# Name: Exterior1st, dtype: int64
#
# The columns is Exterior2nd and have 1 null values from 1459 and data-type is object.
# VinylSd    510
# MetalSd    233
# HdBoard    199
# Wd Sdng    194
# Plywood    128
# CmentBd     66
# Wd Shng     43
# ...

# %%
for i in tr_data:
    
    if((tr_data[i].dtype == 'int') or (tr_data[i].dtype == 'float')):
                
        plt.figure(figsize = (16,6))

        plt.subplot(1,2,1)
        sns.regplot(x=tr_data[i], y="SalePrice", data=tr_data);
        plt.title(i)

        plt.subplot(1,2,2)
        plt.scatter(x = tr_data[i], y = tr_data["SalePrice"], s = 8)
        plt.title("Sales Price vs %s" % (i))

# %%
for i in tr_data:
  
    if (tr_data[i].dtype == 'object'):
        
        plt.figure(figsize = (16,6))

        plt.subplot(1,2,1)
        sns.stripplot(x=tr_data[i], y="YearBuilt", data=tr_data, palette="husl")
        plt.title(i)

        plt.subplot(1,2,2)
        plt.scatter(x = tr_data[i], y = tr_data["SalePrice"], s = 8)
        plt.title(i)
# Out:
# <ipython-input-40-596280b41d79>:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize = (16,6))

# %%
#Encode the categorical data in train and test dataframe
for i in tr_data:
    if(tr_data[i].dtype == 'object'):
        tr_data[i] = labelencoder.fit_transform(tr_data[i])
        
for i in tt_data:
    if(tt_data[i].dtype == 'object'):
        tt_data[i] = labelencoder.fit_transform(tt_data[i])

# %%
X = tr_data.iloc[:, 0:74]
Y = tr_data.iloc[:, 74]

#Split the Train-Data to 80%-Train and 20-Test
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
lr.fit(x_train, y_train)
print('Linear-Regression Accuracy score is: ' , lr.score(x_train,y_train))

# Make predictions using the testing set
y_pred = lr.predict(x_test)
# Out:
# Linear-Regression Accuracy score is:  0.8856957933870594
