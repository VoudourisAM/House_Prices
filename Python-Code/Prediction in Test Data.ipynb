# %%
pred_test_data = lr.predict(tt_data)
tt_data['Linear Model'] = pred_test_data
tt_data['Feature'] = features

# %%
tt_data.head(10)
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  LandContour  \
# 0          20         2         80.0    11622       1         3            3
# 1          20         3         81.0    14267       1         0            3
# 2          60         3         74.0    13830       1         0            3
# 3          60         3         78.0     9978       1         0            3
# 4         120         3         43.0     5005       1         0            1
# 5          60         3         75.0    10000       1         0            3
# 6          20         3         63.0     7980       1         0            3
# 7          60         3         63.0     8402       1         0            3
# 8          20         3         85.0    10176       1         3            3
# 9          20         3         70.0     8400       1         3            3
#
#    Utilities  LotConfig  LandSlope  ...  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
tt_data.drop(tt_data.columns.difference(['Linear Model','Feature']), 1, inplace=True)
tt_data.head(10)
# Out:
#     Linear Model        Feature
# 0  123424.004408  169277.052498
# 1  201560.608184  187758.393989
# 2  178305.055272  183583.683570
# 3  185534.934329  179317.477511
# 4  181855.030612  150730.079977
# 5  169222.244334  177150.989247
# 6  183344.735400  172070.659229
# 7  156930.318010  175110.956520
# 8  200307.719334  162011.698832
# 9  102737.737222  160726.247831

# %%
plt.figure(figsize = (16,6))

fig = sns.kdeplot(tt_data['Linear Model'], shade=False, color="b")
fig = sns.kdeplot(tt_data['Feature'], shade=False, color="r")
plt.show()

# %%
plt.figure(figsize = (16,6))

sns.lineplot(data=tt_data)
# Out:
# <AxesSubplot:>
